# %%
import torch
print(torch.__version__)
# Out:
# '.venv' でセルを実行するには、 ipykernel パッケージが必要です。
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/dl-box/Desktop/kiuchi/Toyota/mag/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
